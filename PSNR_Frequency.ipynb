# %%
#PSNR low pass
import cv2
import numpy as np

lp=[]
for i in range(2,10):
    img1 = cv2.imread('sp0{}.jpg'.format(i))
    img2 = cv2.imread('LPSP_nonax{}0.jpg'.format(i))
    lp.append(cv2.PSNR(img1,img2))
# Out:
# [11.43670960518956, 10.039857866043668, 9.040473754410828, 8.274905967236284, 7.660498975121721, 7.153079915682809, 6.731710191575571, 6.377136125002591]

# %%
#PSNR band pass
import cv2
import numpy as np

bp=[]
for i in range(2,10):
    img1 = cv2.imread('sp0{}.jpg'.format(i))
    img2 = cv2.imread('BPF_nonax{}0.jpg'.format(i))
    bp.append(cv2.PSNR(img1,img2))

# %%
#PSNR low pass-band pass 그래프
import matplotlib.pyplot as plt

X=[20,30,40,50,60,70,80,90]
Y_1=lp
Y_2=bp

plt.plot(X,Y_1,linestyle='-',marker='o',c='darkcyan',label='Low pass') #파란색 그래프
plt.plot(X,Y_2,linestyle='-',marker='D',c='darkmagenta',label='Band pass') #주황색 그래프
plt.legend(shadow=False, fancybox=False, loc='upper right')
plt.title('PSNR'),plt.xlabel('bins'),plt.ylabel('conunt')
plt.tight_layout()
plt.savefig('PSNR_LPBP.jpg')
plt.show()

# %%
#PSNR high pass
import cv2
import numpy as np

hp.append(cv2.PSNR(img1,img2))

# %%
#PSNR band pass
import cv2
import numpy as np

bs=[]
for i in range(2,10):
    img1 = cv2.imread('sp0{}.jpg'.format(i))
    img2 = cv2.imread('BS_noax{}0.jpg'.format(i))
    bs.append(cv2.PSNR(img1,img2))

# %%
#PSNR low pass-band pass 그래프
X=[20,30,40,50,60,70,80,90]
Y_1=hp
Y_2=bs

plt.plot(X,Y_1,linestyle='-',marker='o',c='darkcyan',label='High pass') #파란색 그래프
plt.plot(X,Y_2,linestyle='-',marker='D',c='darkmagenta',label='Band stop') #주황색 그래프
plt.legend(shadow=False, fancybox=False, loc='upper right')
plt.title('PSNR'),plt.xlabel('bins'),plt.ylabel('conunt')
plt.tight_layout()
plt.savefig('PSNR_HPBS.jpg')
plt.show()
